# %%
import pandas as pd
import numpy as np
from dateutil.parser import parse

# %%
data1 = pd.read_csv("../data1.csv")
data2 = pd.read_csv("../data2.csv")

# %%
dt = parse(data1["datetime"])
print(dt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-1048f0198e45> in <module>()
# ----> 1 dt = parse(data1["datetime"])
#       2 print(dt)
#
# C:\Program Files\Anaconda2\envs\py35\lib\site-packages\dateutil\parser.py in parse(timestr, parserinfo, **kwargs)
#    1166         return parser(parserinfo).parse(timestr, **kwargs)
#    1167     else:
# -> 1168         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1169
#    1170
#
# C:\Program Files\Anaconda2\envs\py35\lib\site-packages\dateutil\parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     554             effective_dt = default
#     555
# --> 556         res, skipped_tokens = self._parse(timestr, **kwargs)
#     557
#     558         if res is None:
#
# ...

# %%
import matplotlib
y1 = data1["rssi"]
#dates = matplotlib.dates.date2num(data1["datetime"])
x1 = data1["idalat"]
matplotlib.pyplot.plot(x1,y1)
plt.gcf()
